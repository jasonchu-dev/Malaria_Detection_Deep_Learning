# %%
import cv2 as cv
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.models import Sequential

# %%
training_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

training_set = training_datagen.flow_from_directory('Dataset/Train', target_size=(225, 225), batch_size=32, class_mode='categorical')
test_set = training_datagen.flow_from_directory('Dataset/Test', target_size=(225, 225), batch_size=32, class_mode='categorical')
# Out:
# Found 416 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.

# %%
model = Sequential()

model.add(Conv2D(16, (3, 3), input_shape=(225, 225, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(164, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(328, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(training_set, validation_data=test_set, epochs=15, steps_per_epoch=len(training_set), validation_steps=len(test_set))
# Out:
# Epoch 1/15
# 13/13 [==============================] - 5s 295ms/step - loss: 0.7052 - accuracy: 0.5577 - val_loss: 0.6741 - val_accuracy: 0.6791
# Epoch 2/15
# 13/13 [==============================] - 3s 268ms/step - loss: 0.6930 - accuracy: 0.5264 - val_loss: 0.6922 - val_accuracy: 0.4627
# Epoch 3/15
# 13/13 [==============================] - 4s 299ms/step - loss: 0.6937 - accuracy: 0.4808 - val_loss: 0.6891 - val_accuracy: 0.6791
# Epoch 4/15
# 13/13 [==============================] - 4s 313ms/step - loss: 0.6921 - accuracy: 0.5288 - val_loss: 0.6806 - val_accuracy: 0.6791
# Epoch 5/15
# 13/13 [==============================] - 4s 296ms/step - loss: 0.6848 - accuracy: 0.5793 - val_loss: 0.7300 - val_accuracy: 0.3806
# Epoch 6/15
# 13/13 [==============================] - 4s 316ms/step - loss: 0.6306 - accuracy: 0.6442 - val_loss: 0.7933 - val_accuracy: 0.4104
# Epoch 7/15
# 13/13 [==============================] - 4s 305ms/step - loss: 0.5004 - accuracy: 0.7524 - val_loss: 0.4894 - val_accuracy: 0.8209
# Epoch 8/15
# 13/13 [==============================] - 4s 292ms/step - loss: 0.3526 - accuracy: 0.8894 - val_loss: 0.4049 - val_accuracy: 0.8134
# Epoch 9/15
# 13/13 [==============================] - 4s 317ms/step - loss: 0.2473 - accuracy: 0.9135 - val_loss: 0.3612 - val_accuracy: 0.8731
# Epoch 10/15
# 13/13 [==============================] - 4s 311ms/step - loss: 0.1592 - accuracy: 0.9471 - val_loss: 0.3224 - val_accuracy: 0.8507
# Epoch 11/15
# 13/13 [==============================] - 4s 296ms/step - loss: 0.1909 - accuracy: 0.9327 - val_loss: 0.1648 - val_accuracy: 0.9328
# Epoch 12/15
# 13/13 [==============================] - 4s 276ms/step - loss: 0.1382 - accuracy: 0.9663 - val_loss: 0.2083 - val_accuracy: 0.9254
# Epoch 13/15
# 13/13 [==============================] - 4s 280ms/step - loss: 0.1319 - accuracy: 0.9615 - val_loss: 0.0882 - val_accuracy: 0.9701
# Epoch 14/15
# 13/13 [==============================] - 4s 334ms/step - loss: 0.0430 - accuracy: 0.9856 - val_loss: 0.1042 - val_accuracy: 0.9478
# Epoch 15/15
# 13/13 [==============================] - 4s 291ms/step - loss: 0.0281 - accuracy: 0.9952 - val_loss: 0.0894 - val_accuracy: 0.9552

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_45 (Conv2D)          (None, 225, 225, 16)      448
#
#  max_pooling2d_45 (MaxPoolin  (None, 112, 112, 16)     0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 112, 112, 32)      4640
#
#  max_pooling2d_46 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 56, 56, 64)        18496
#
#  max_pooling2d_47 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_48 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_48 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 14, 14, 164)       189092
#
#  max_pooling2d_49 (MaxPoolin  (None, 7, 7, 164)        0
#  g2D)
#
#  conv2d_50 (Conv2D)          (None, 7, 7, 328)         484456
#
#  max_pooling2d_50 (MaxPoolin  (None, 3, 3, 328)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 2952)              0
#
#  dense_20 (Dense)            (None, 500)               1476500
#
#  dense_21 (Dense)            (None, 2)                 1002
#
# =================================================================
# Total params: 2,248,490
# Trainable params: 2,248,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
DIR = '/home/jovyan/work/Malaria_Detection/Dataset/Test'

wrong = 0
right = 0

b = []
c = 0

for i in os.listdir(DIR):
    path = os.path.join(DIR, i)
    for j in os.listdir(path):
        img = cv.imread(path+'/'+j)
        img = cv.resize(img, (225, 225))
        img = img.reshape(1, 225, 225, 3)
        img = img/255
        a = np.argmax(model.predict(img, verbose=0), axis=1)
        if a == 0:
            if i == 'Parasite': right += 1
            else: wrong += 1
            print(c, 'infected')
            b.append('infected')
        else:
            if i == 'Uninfected': right += 1
            else: wrong += 1
            print(c, 'uninfected')
            b.append('uninfected')
        c += 1
# Out:
# 0 infected
# 1 infected
# 2 infected
# 3 infected
# 4 infected
# 5 infected
# 6 infected
# 7 infected
# 8 infected
# 9 infected
# 10 infected
# 11 uninfected
# 12 infected
# 13 infected
# 14 infected
# 15 infected
# 16 infected
# 17 infected
# 18 infected
# 19 infected
# 20 uninfected
# 21 infected
# 22 infected
# 23 infected
# 24 infected
# 25 infected
# 26 infected
# 27 infected
# 28 infected
# 29 infected
# 30 infected
# 31 infected
# 32 infected
# 33 uninfected
# 34 infected
# 35 infected
# 36 infected
# 37 infected
# 38 infected
# 39 infected
# 40 infected
# 41 infected
# 42 infected
# 43 infected
# 44 infected
# 45 infected
# 46 infected
# 47 infected
# 48 infected
# 49 infected
# 50 infected
# 51 infected
# 52 infected
# 53 infected
# 54 infected
# 55 infected
# 56 infected
# 57 infected
# 58 infected
# 59 infected
# 60 infected
# 61 infected
# 62 infected
# 63 uninfected
# 64 infected
# 65 infected
# 66 infected
# 67 uninfected
# 68 infected
# 69 infected
# 70 infected
# 71 infected
# 72 infected
# 73 infected
# 74 infected
# 75 infected
# 76 infected
# 77 infected
# 78 infected
# 79 infected
# 80 infected
# 81 infected
# 82 infected
# 83 infected
# 84 infected
# 85 infected
# 86 infected
# 87 infected
# 88 uninfected
# 89 infected
# 90 infected
# 91 uninfected
# 92 uninfected
# 93 uninfected
# 94 uninfected
# 95 uninfected
# 96 uninfected
# 97 uninfected
# 98 infected
# 99 uninfected
# 100 uninfected
# 101 uninfected
# 102 uninfected
# 103 uninfected
# 104 uninfected
# 105 uninfected
# 106 uninfected
# 107 uninfected
# 108 uninfected
# 109 uninfected
# 110 uninfected
# 111 uninfected
# 112 uninfected
# 113 uninfected
# 114 uninfected
# 115 uninfected
# 116 uninfected
# 117 uninfected
# 118 uninfected
# 119 uninfected
# 120 uninfected
# 121 uninfected
# 122 uninfected
# 123 uninfected
# 124 infected
# 125 uninfected
# 126 uninfected
# 127 uninfected
# 128 uninfected
# 129 uninfected
# 130 uninfected
# 131 uninfected
# 132 uninfected
# 133 uninfected

# %%
total = len(os.listdir('/home/jovyan/work/Malaria_Detection/Dataset/Test/Uninfected')) + len(os.listdir('/home/jovyan/work/Malaria_Detection/Dataset/Test/Parasite'))
print(f'Correct: {(right/(right + wrong)) * 100} --> {(right/(right + wrong)) * total}/{float(total)}')
print(f'Incorrect: {(wrong/(right + wrong)) * 100} --> {(wrong/(right + wrong)) * total}/{float(total)}')
# Out:
# Correct: 94.02985074626866 --> 126.0/134.0
# Incorrect: 5.970149253731343 --> 8.0/134.0
